# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("book_sales.csv")

# %%
print(df.head())
# Out:
#          Date  Paperback  Hardcover  Time
# 0  2000-04-01        199        139     0
# 1  2000-04-02        172        128     1
# 2  2000-04-03        111        172     2
# 3  2000-04-04        209        139     3
# 4  2000-04-05        161        191     4

# %%
df['Time'] = np.arange(len(df.index))

# %%
plt.plot(df['Time'], df['Hardcover'])

# %%
sns.regplot(x=df['Time'], y=df['Hardcover'])
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Hardcover'>
